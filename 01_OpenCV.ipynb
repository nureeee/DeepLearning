# %% [markdown]
# <a href="https://colab.research.google.com/github/nureeee/DeepLearning/blob/main/01_OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. File Upload

# %%
from google.colab import files
upload_file = files.upload()
# Out:
#      <input type="file" id="files-8525e45d-293e-4101-b08b-817deefaff6d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8525e45d-293e-4101-b08b-817deefaff6d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving car1.jpg to car1.jpg

# %% [markdown]
# 코랩에는 openCV가 깔려 있다.

# %% [markdown]
# # 2.OpenCV 기본 함수

# %%
import cv2
import numpy as np

# %%
print('OpenCV version : {}'.format(cv2.__version__))
# Out:
# OpenCV version : 4.1.2

# %% [markdown]
# # 3. 이미지 읽고 보기

# %%
file_name = 'car1.jpg'
img = cv2.imread(file_name)

# %%
cv2.imshow('MyCar', img) # 오류
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-7-6d0aec1ca6f8> in <module>()
# ----> 1 cv2.imshow('MyCar', img) # 오류
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      50   def wrapped(*args, **kwargs):
#      51     if not os.environ.get(env_var, False):
# ---> 52       raise DisabledFunctionError(message, name or func.__name__)
#      53     return func(*args, **kwargs)
#      54
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %% [markdown]
# # 코랩에서 이미지 띄워주기

# %%
import matplotlib.pyplot as plt

plt.imshow(img)
plt.show()

# %% [markdown]
# # !!!!!!!!!!!!!컬러패널 바꾸기!!!!!!!!!!!!

# %%
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(rgb_img)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(gray_img, 'gray')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
print('image Height : {}'.format(img.shape[0]))
print('image Width : {}'.format(img.shape[1]))
print('image Channel : {}'.format(img.shape[2]))
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F861E9C9310>
# image Height : 720
# image Width : 1280
# image Channel : 3

# %%
import PIL.Image as Image

Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F861E9E4AD0>
